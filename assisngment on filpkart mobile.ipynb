# %%
import requests
from bs4 import BeautifulSoup

# %%
page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    url="https://www.flipkart.com/search?q=realme+mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_na&as-pos=1&as-type=RECENT&suggestionId=realme+mobile%7CMobiles&requestId=f911896e-bfce-4f95-b3ef-1e51ed08f2dc&as-searchtext=r&page="+str(i)
    req=requests.get(url)
    content=BeautifulSoup(req.content,'html.parser')
    print(content)
# Out:
# Enter number of pages2
# <!DOCTYPE html>
# ...

# %%
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.116d54.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
names=content.find_all('div',{"class":"_4rR01T"})
prices=content.find_all('div',{"class":"_30jeq3 _1_WHN1"})
ratings=content.find_all('div',{"class":"_3LWZlK"})

# %%
print(len(names))
# Out:
# 24

# %%
names
# Out:
# [<div class="_4rR01T">realme C31 (Light Silver, 64 GB)</div>,
#  <div class="_4rR01T">realme C25_Y (Glacier Blue, 128 GB)</div>,
#  <div class="_4rR01T">realme C35 (Glowing Green, 64 GB)</div>,
#  <div class="_4rR01T">realme C35 (Glowing Black, 64 GB)</div>,
#  <div class="_4rR01T">realme C21 (Cross Black, 32 GB)</div>,
#  <div class="_4rR01T">realme C21 (Cross Black, 64 GB)</div>,
#  <div class="_4rR01T">realme 9 (Sunburst Gold, 128 GB)</div>,
#  <div class="_4rR01T">realme 9 (Stargaze White, 128 GB)</div>,
#  <div class="_4rR01T">realme 9 (Meteor Black, 128 GB)</div>,
#  <div class="_4rR01T">realme 9 (Meteor Black, 128 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme C21 (Cross Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme Narzo 50 (Speed Black, 64 GB)</div>,
#  <div class="_4rR01T">realme 9 Pro 5G (Sunrise Blue, 128 GB)</div>,
#  <div class="_4rR01T">realme 8s 5G (Universe Purple, 128 GB)</div>,
# ...

# %%
print(len(prices))
# Out:
# 24

# %%
prices
# Out:
# [<div class="_30jeq3 _1_WHN1">₹9,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,699</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
# ...

# %%
ratings
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
# ...

# %%
print(len(ratings))
# Out:
# 39

# %%
mob_ph=[]
for i in range(0,len(names)):
    mob_ph.append(names[i].get_text())

# %%
mob_ph
# Out:
# ['realme C31 (Light Silver, 64 GB)',
#  'realme C25_Y (Glacier Blue, 128 GB)',
#  'realme C35 (Glowing Green, 64 GB)',
#  'realme C35 (Glowing Black, 64 GB)',
#  'realme C21 (Cross Black, 32 GB)',
#  'realme C21 (Cross Black, 64 GB)',
#  'realme 9 (Sunburst Gold, 128 GB)',
#  'realme 9 (Stargaze White, 128 GB)',
#  'realme 9 (Meteor Black, 128 GB)',
#  'realme 9 (Meteor Black, 128 GB)',
#  'realme C11 2021 (Cool Blue, 64 GB)',
#  'realme C21 (Cross Blue, 64 GB)',
#  'realme Narzo 50 (Speed Black, 64 GB)',
#  'realme 9 Pro 5G (Sunrise Blue, 128 GB)',
#  'realme 8s 5G (Universe Purple, 128 GB)',
#  'realme Narzo 50i (Mint Green, 32 GB)',
#  'realme Narzo 50i (Mint Green, 64 GB)',
#  'realme Narzo 50i (Carbon Black, 32 GB)',
#  'realme C21Y (Cross Black, 32 GB)',
#  'realme C21Y (Cross Blue, 64 GB)',
#  'realme C21 (Cross Blue, 32 GB)',
#  'realme C35 (Glowing Green, 128 GB)',
#  'realme 8s 5G (Universe Blue, 128 GB)',
#  'realme Narzo 50 (Speed Blue, 128 GB)']

# %%
mob_pri=[]
for i in range(0,len(prices)):
    mob_pri.append(prices[i].get_text())

# %%
mob_pri
# Out:
# ['₹9,999',
#  '₹11,999',
#  '₹11,999',
#  '₹11,999',
#  '₹9,499',
#  '₹10,499',
#  '₹18,999',
#  '₹18,999',
#  '₹18,999',
#  '₹17,999',
#  '₹8,999',
#  '₹10,499',
#  '₹12,999',
#  '₹18,999',
#  '₹17,999',
#  '₹7,499',
#  '₹8,999',
#  '₹7,499',
#  '₹9,499',
#  '₹8,699',
#  '₹9,499',
#  '₹12,999',
#  '₹17,999',
#  '₹14,499']

# %%
mob_rati=[]
for i in range(0,len(ratings)):
    mob_rati.append(ratings[i].get_text())

# %%
mob_rati
# Out:
# ['4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.6',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.5',
#  '4.6',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '5',
#  '5',
#  '4.3',
#  '5',
#  '4',
#  '4.5',
#  '5',
#  '3',
#  '4.4',
#  '1',
#  '1',
#  '4.4',
#  '5',
#  '4']

# %%
import pandas as pd

# %%
data={"mobile name":mob_ph,"mobile price":mob_pri}
df=pd.DataFrame(data)
print(df)
# Out:
#                                mobile name mobile price
# 0         realme C31 (Light Silver, 64 GB)       ₹9,999
# 1      realme C25_Y (Glacier Blue, 128 GB)      ₹11,999
# 2        realme C35 (Glowing Green, 64 GB)      ₹11,999
# 3        realme C35 (Glowing Black, 64 GB)      ₹11,999
# 4          realme C21 (Cross Black, 32 GB)       ₹9,499
# 5          realme C21 (Cross Black, 64 GB)      ₹10,499
# 6         realme 9 (Sunburst Gold, 128 GB)      ₹18,999
# 7        realme 9 (Stargaze White, 128 GB)      ₹18,999
# 8          realme 9 (Meteor Black, 128 GB)      ₹18,999
# 9          realme 9 (Meteor Black, 128 GB)      ₹17,999
# 10      realme C11 2021 (Cool Blue, 64 GB)       ₹8,999
# 11          realme C21 (Cross Blue, 64 GB)      ₹10,499
# 12    realme Narzo 50 (Speed Black, 64 GB)      ₹12,999
# 13  realme 9 Pro 5G (Sunrise Blue, 128 GB)      ₹18,999
# 14  realme 8s 5G (Universe Purple, 128 GB)      ₹17,999
# 15    realme Narzo 50i (Mint Green, 32 GB)       ₹7,499
# ...
